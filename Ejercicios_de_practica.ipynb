# %%
edad = 20
if edad >= 18:
    print("Mayor de edad")
# Out:
# Mayor de edad

# %%
temperatura = 25
if temperatura > 30:
 print("Alta")
else:
 print("Normal")
# Out:
# Normal

# %%
numero = 7
if numero % 2 == 0:
 print("Par")
else:
 print("Impar")
# Out:
# Impar

# %%
nota = 4.2
if nota >= 4.5:
 print("Excelente")
elif nota >= 4.0:
 print("Muy buen desempeño")
elif nota >= 3.0:
 print("Aprobado")
else:
 print("No aprobado")
# Out:
# Muy buen desempeño

# %%
nota = 4.8
if nota >= 4.5 :
 print("Excelente")
elif nota >= 3.0:
 print("Aprobado")
# Out:
# Excelente

# %%
valor = 12
if valor < 5:
 print("A")
elif valor < 10:
 print("B")
elif valor < 15:
 print("C")
else:
 print("D")
# Out:
# C

# %%
usuario_activo = True
tiene_permiso = True
if usuario_activo and tiene_permiso:
 print("Acceso permitido")
else:
 print("Acceso denegado")
# Out:
# Acceso permitido

# %%
correo_valido = False
telefono_valido = True
if correo_valido and telefono_valido:
 print("Continuar registro")
else:
 print("Faltan datos de contacto")
# Out:
# Faltan datos de contacto

# %%
cuenta_bloqueada = False
if not cuenta_bloqueada:
 print("Puede operar")
# Out:
# Puede operar

# %%
for numero in range(1,6):
 print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for numero in range(2,11,2):
 print(numero)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# # Predice el acumulado
# ```
# suma = 0
# for i in range(1, 4):
#  suma = suma + i
# print(suma)
# ```
# = 6

# %%
numero = 1
while numero <= 5:
 print(numero)
 numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # Encuentra el ciclo infinito
#
#
# ```
# numero = 1
# while numero <= 5:
#  print(numero)
#  ____
# ### Respuesta: numero = numero + 1
# ```

# %%
intentos = 0
while intentos < 3:
 clave = input("Ingrese la clave: ")
 intentos = intentos + 1
print("Proceso finalizado")
# Out:
# Ingrese la clave: 456
# Ingrese la clave: 466
# Ingrese la clave: 456
# Proceso finalizado

# %% [markdown]
# Procesar exactamente 10 mediciones. ___For___ ,
# Pedir una clave hasta que sea correcta. ___While___,
# Imprimir los números del 1 al 20. ____For____,
# Repetir un cálculo hasta que el error sea menor que 0.01. ___While___.

# %%
for numero in range(1, 13):
    if numero % 3 == 0 :
        print(numero)
# Out:
# 3
# 6
# 9
# 12

# %%
for numero in range(1, 8):
    if numero < 3:
        print(numero, "A")
    elif numero < 6:
        print(numero, "B")
    else:
        print(numero, "C")
# Out:
# 1 A
# 2 A
# 3 B
# 4 B
# 5 B
# 6 C
# 7 C

# %%
nota = float(input("Nota: "))
if nota >= 3.0:
   print("Aprobado")
else:
   print("No aprobado")
# Out:
# Nota: 3.5
# Aprobado

# %%
for i in range(1, 6 ):
 print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for temperatura in range(5):
    t = float(input("Temperatura:   "))
    if t < 18:
        print("Baja")
    elif t <= 25:
        print("Normal")
    else:
        print("Alta")
# Out:
# Temperatura:   23
# Normal
# Temperatura:   29
# Alta
# Temperatura:   30
# Alta
# Temperatura:   5
# Baja
# Temperatura:   1
# Baja
